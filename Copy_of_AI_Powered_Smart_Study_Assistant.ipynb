# %% [markdown]
# <a href="https://colab.research.google.com/github/AgnusSerena/AI_Study_Assistant/blob/main/Copy_of_AI_Powered_Smart_Study_Assistant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai

# %%
from google import genai
from google.colab import userdata

# %%
client=genai.Client(api_key=userdata.get("GEMINI_API_KEY"))
print(client)

# %%
def study_assistant(user_prompt):
  response=client.models.generate_content(
      model="gemini-2.5-flash",
      contents=user_prompt
  )
  return response

# %%
output=study_assistant("explain LLM Architecture")
print (output.text)
# Out:
# Large Language Models (LLMs) are primarily based on the **Transformer architecture**, specifically a **decoder-only** variant of it. This architecture was introduced in the "Attention Is All You Need" paper (2017) and revolutionized sequence-to-sequence modeling, becoming the foundation for most modern LLMs like GPT series, LLaMA, Bard, Claude, etc.
#
# Let's break down the LLM architecture:
#
# ### 1. The Core Idea: Autoregressive Decoder-Only Transformer
#
# Instead of the original Encoder-Decoder Transformer designed for translation (where an encoder processes the input sentence and a decoder generates the output sentence), modern LLMs primarily use a **decoder-only** architecture.
#
# *   **Decoder-only:** This means the model is designed to generate sequences *one token at a time*, always looking at the previously generated tokens. This is an **autoregressive** process.
# ...
